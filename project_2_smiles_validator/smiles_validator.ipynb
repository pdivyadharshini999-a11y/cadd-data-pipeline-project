# %%
# !pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.0/37.0 MB 37.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from rdkit import Chem

# %%
data = pd.read_csv("clean_data.csv")

# %%
data.head()
# Out:
#                                               SMILES  pIC50  \
# 0         O=S(=O)(Nc1cccc(-c2cnc3ccccc3n2)c1)c1cccs1   4.26
# 1  O=c1cc(-c2nc(-c3ccc(-c4cn(CCP(=O)(O)O)nn4)cc3)...   4.34
# 2             NC(=O)c1ccc2c(c1)nc(C1CCC(O)CC1)n2CCCO   4.53
# 3                NCCCn1c(C2CCNCC2)nc2cc(C(N)=O)ccc21   4.56
# 4                  CNC(=S)Nc1cccc(-c2cnc3ccccc3n2)c1   4.59
#
#                                                 mol  num_atoms    logP
# 0  <rdkit.Chem.rdchem.Mol object at 0x7f59df45bc30>         25  4.1591
# 1  <rdkit.Chem.rdchem.Mol object at 0x7f59a320c9e0>         36  3.6743
# 2  <rdkit.Chem.rdchem.Mol object at 0x7f59a320cac0>         23  1.5361
# 3  <rdkit.Chem.rdchem.Mol object at 0x7f59a320cba0>         22  0.9510
# 4  <rdkit.Chem.rdchem.Mol object at 0x7f59a320c7b0>         21  3.2130

# %%
data.tail()
# Out:
#                                       SMILES  pIC50  \
# 16062   S=C(NN=C(c1ccccn1)c1ccccn1)Nc1ccccc1   0.00
# 16063                S=C=NCCCCCCCCCCc1ccccc1   0.00
# 16064                  S=C=NCCCCCCCCc1ccccc1   0.00
# 16065  S=c1[nH]nc(Cn2ccc3ccccc32)n1-c1ccccc1   0.00
# 16066       N=[N+]=NC=Cc1ccc([N+](=O)[O-])o1   0.02
#
#                                                     mol  num_atoms     logP
# 16062  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ed50>         24  3.21560
# 16063  <rdkit.Chem.rdchem.Mol object at 0x7f59a314edc0>         19  5.45270
# 16064  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ee30>         17  4.67250
# 16065  <rdkit.Chem.rdchem.Mol object at 0x7f59a314eea0>         22  3.93289
# 16066  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ef10>         13  1.70887

# %%
data.describe()
# Out:
#               pIC50     num_atoms          logP
# count  16067.000000  16067.000000  16067.000000
# mean       0.999948     18.691666      2.254606
# std        2.398541      8.266598      1.606149
# min        0.000000      3.000000     -5.395600
# 25%        0.000000     13.000000      1.213600
# 50%        0.020000     17.000000      2.161820
# 75%        0.265000     23.000000      3.230000
# max       10.970000     59.000000     10.012900

# %%
data.isnull().sum()
# Out:
# SMILES       0
# pIC50        0
# mol          0
# num_atoms    0
# logP         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['SMILES', 'pIC50', 'mol', 'num_atoms', 'logP'], dtype='object')

# %%
valid_rows = []

for i, smile in enumerate (data["SMILES"]):
  mol = Chem.MolFromSmiles(smile)
  if mol is None:
    print(smile, "= invalid")
  else:
    print(smile, "= valid")
    valid_rows.append(data.iloc[i])
# Out:
# Streaming output truncated to the last 5000 lines.
# Cc1nc([N+](=O)[O-])c(Cl)n1C = valid
# Cc1nc(Cl)c([N+](=O)[O-])n1C = valid
# CC(C)COC(=O)C=Cc1ccc([N+](=O)[O-])o1 = valid
# CN(CC=CC#CC(C)(C)C)Cc1cccc2ccccc12 = valid
# CCCCNC(=O)C=Cc1ccc([N+](=O)[O-])o1 = valid
# NC(=O)OCCc1c[nH]c2ccccc12 = valid
# CCCN(CCC)CCc1cccc2c1CC(=O)N2 = valid
# C=CCC1(C(C)(C)C)C(=O)NC(=O)NC1=O = valid
# COc1c(OC)c(OC(C)=O)c2cc(Cl)ccc2c1OC(C)=O = valid
# O=C(O)CCC1=NS(=O)(=O)c2cc(Br)ccc2N1 = valid
# O=C(O)CCC1=NS(=O)(=O)c2cc(Cl)ccc2N1 = valid
# CN(C)C(=O)OCCCc1ccccc1 = valid
# NC1=NCC(CN2CCN(c3ccccc3)CC2)O1 = valid
# CCCCCOC(=O)C=Cc1ccc([N+](=O)[O-])o1 = valid
# COc1c(OC)c(OC(=O)C(C)(C)C)c2ccccc2c1OC(=O)C(C)(C)C = valid
# COc1c(OC)c(OC(C)=O)c2c(Cl)cccc2c1OC(C)=O = valid
# COc1c(OC)c(OC(C)=O)c2cc(F)ccc2c1OC(C)=O = valid
# COc1c(OC)c(OC(C)=O)c2cc(Br)ccc2c1OC(C)=O = valid
# COc1c(OC)c(OC(C)=O)c2c(OC)cccc2c1OC(C)=O = valid
# COc1c(OC)c(OC(C)=O)c2c(C#N)cccc2c1OC(C)=O = valid
# ...

# %%
print(len(valid_rows))
# Out:
# 16067

# %%
df_valid_rows = pd.DataFrame(valid_rows)

# %%
df_valid_rows.head()
# Out:
#                                               SMILES  pIC50  \
# 0         O=S(=O)(Nc1cccc(-c2cnc3ccccc3n2)c1)c1cccs1   4.26
# 1  O=c1cc(-c2nc(-c3ccc(-c4cn(CCP(=O)(O)O)nn4)cc3)...   4.34
# 2             NC(=O)c1ccc2c(c1)nc(C1CCC(O)CC1)n2CCCO   4.53
# 3                NCCCn1c(C2CCNCC2)nc2cc(C(N)=O)ccc21   4.56
# 4                  CNC(=S)Nc1cccc(-c2cnc3ccccc3n2)c1   4.59
#
#                                                 mol  num_atoms    logP
# 0  <rdkit.Chem.rdchem.Mol object at 0x7f59df45bc30>         25  4.1591
# 1  <rdkit.Chem.rdchem.Mol object at 0x7f59a320c9e0>         36  3.6743
# 2  <rdkit.Chem.rdchem.Mol object at 0x7f59a320cac0>         23  1.5361
# 3  <rdkit.Chem.rdchem.Mol object at 0x7f59a320cba0>         22  0.9510
# 4  <rdkit.Chem.rdchem.Mol object at 0x7f59a320c7b0>         21  3.2130

# %%
df_valid_rows.tail()
# Out:
#                                       SMILES  pIC50  \
# 16062   S=C(NN=C(c1ccccn1)c1ccccn1)Nc1ccccc1   0.00
# 16063                S=C=NCCCCCCCCCCc1ccccc1   0.00
# 16064                  S=C=NCCCCCCCCc1ccccc1   0.00
# 16065  S=c1[nH]nc(Cn2ccc3ccccc32)n1-c1ccccc1   0.00
# 16066       N=[N+]=NC=Cc1ccc([N+](=O)[O-])o1   0.02
#
#                                                     mol  num_atoms     logP
# 16062  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ed50>         24  3.21560
# 16063  <rdkit.Chem.rdchem.Mol object at 0x7f59a314edc0>         19  5.45270
# 16064  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ee30>         17  4.67250
# 16065  <rdkit.Chem.rdchem.Mol object at 0x7f59a314eea0>         22  3.93289
# 16066  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ef10>         13  1.70887

# %%
df_valid_rows.to_csv("valid_smiles.csv",index=False)

# %%
check = pd.read_csv("valid_smiles.csv")

# %%
check.head()
# Out:
#                                               SMILES  pIC50  \
# 0         O=S(=O)(Nc1cccc(-c2cnc3ccccc3n2)c1)c1cccs1   4.26
# 1  O=c1cc(-c2nc(-c3ccc(-c4cn(CCP(=O)(O)O)nn4)cc3)...   4.34
# 2             NC(=O)c1ccc2c(c1)nc(C1CCC(O)CC1)n2CCCO   4.53
# 3                NCCCn1c(C2CCNCC2)nc2cc(C(N)=O)ccc21   4.56
# 4                  CNC(=S)Nc1cccc(-c2cnc3ccccc3n2)c1   4.59
#
#                                                 mol  num_atoms    logP
# 0  <rdkit.Chem.rdchem.Mol object at 0x7f59df45bc30>         25  4.1591
# 1  <rdkit.Chem.rdchem.Mol object at 0x7f59a320c9e0>         36  3.6743
# 2  <rdkit.Chem.rdchem.Mol object at 0x7f59a320cac0>         23  1.5361
# 3  <rdkit.Chem.rdchem.Mol object at 0x7f59a320cba0>         22  0.9510
# 4  <rdkit.Chem.rdchem.Mol object at 0x7f59a320c7b0>         21  3.2130

# %%
check.tail()
# Out:
#                                       SMILES  pIC50  \
# 16062   S=C(NN=C(c1ccccn1)c1ccccn1)Nc1ccccc1   0.00
# 16063                S=C=NCCCCCCCCCCc1ccccc1   0.00
# 16064                  S=C=NCCCCCCCCc1ccccc1   0.00
# 16065  S=c1[nH]nc(Cn2ccc3ccccc32)n1-c1ccccc1   0.00
# 16066       N=[N+]=NC=Cc1ccc([N+](=O)[O-])o1   0.02
#
#                                                     mol  num_atoms     logP
# 16062  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ed50>         24  3.21560
# 16063  <rdkit.Chem.rdchem.Mol object at 0x7f59a314edc0>         19  5.45270
# 16064  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ee30>         17  4.67250
# 16065  <rdkit.Chem.rdchem.Mol object at 0x7f59a314eea0>         22  3.93289
# 16066  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ef10>         13  1.70887
