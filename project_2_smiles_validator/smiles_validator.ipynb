# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (2026.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)

# %%
import pandas as pd
from rdkit import Chem

# %%
data = pd.read_csv("clean_data.csv")

# %%
data.head()
# Out:
#   Molecule_Name                         SMILES  Solubility_Score  \
# 0       Aspirin       CC(=O)OC1=CC=CC=C1C(=O)O               1.2
# 1     Ibuprofen  CC(C)CC1=CC=C(C=C1)C(C)C(=O)O               0.8
# 2     Unknown_X                        Unknown              -2.5
# 3       Aspirin   CN1C=NC2=C1C(=O)N(C(=O)N2C)C               1.5
#
#    Binding_Affinity
# 0              75.0
# 1              67.5
# 2              82.0
# 3              55.0

# %%
data.tail()
# Out:
#   Molecule_Name                         SMILES  Solubility_Score  \
# 0       Aspirin       CC(=O)OC1=CC=CC=C1C(=O)O               1.2
# 1     Ibuprofen  CC(C)CC1=CC=C(C=C1)C(C)C(=O)O               0.8
# 2     Unknown_X                        Unknown              -2.5
# 3       Aspirin   CN1C=NC2=C1C(=O)N(C(=O)N2C)C               1.5
#
#    Binding_Affinity
# 0              75.0
# 1              67.5
# 2              82.0
# 3              55.0

# %%
data.describe()
# Out:
#        Solubility_Score  Binding_Affinity
# count          4.000000          4.000000
# mean           0.250000         69.875000
# std            1.855622         11.549711
# min           -2.500000         55.000000
# 25%           -0.025000         64.375000
# 50%            1.000000         71.250000
# 75%            1.275000         76.750000
# max            1.500000         82.000000

# %%
data.isnull().sum()
# Out:
# Molecule_Name       0
# SMILES              0
# Solubility_Score    0
# Binding_Affinity    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Molecule_Name', 'SMILES', 'Solubility_Score', 'Binding_Affinity'], dtype='object')

# %%
valid_rows = []

for i, smile in enumerate (data["SMILES"]):
  mol = Chem.MolFromSmiles(smile)
  if mol is None:
    print(smile, "= invalid")
  else:
    print(smile, "= valid")
    valid_rows.append(data.iloc[i])
# Out:
# CC(=O)OC1=CC=CC=C1C(=O)O = valid
# CC(C)CC1=CC=C(C=C1)C(C)C(=O)O = valid
# Unknown = invalid
# CN1C=NC2=C1C(=O)N(C(=O)N2C)C = valid

# %%
print(len(valid_rows))
# Out:
# 3

# %%
df_valid_rows = pd.DataFrame(valid_rows)
# Out:
#   Molecule_Name                         SMILES  Solubility_Score  \
# 0       Aspirin       CC(=O)OC1=CC=CC=C1C(=O)O               1.2
# 1     Ibuprofen  CC(C)CC1=CC=C(C=C1)C(C)C(=O)O               0.8
# 3       Aspirin   CN1C=NC2=C1C(=O)N(C(=O)N2C)C               1.5
#
#    Binding_Affinity
# 0              75.0
# 1              67.5
# 3              55.0

# %%
df_valid_rows.head()
# Out:
#   Molecule_Name                         SMILES  Solubility_Score  \
# 0       Aspirin       CC(=O)OC1=CC=CC=C1C(=O)O               1.2
# 1     Ibuprofen  CC(C)CC1=CC=C(C=C1)C(C)C(=O)O               0.8
# 3       Aspirin   CN1C=NC2=C1C(=O)N(C(=O)N2C)C               1.5
#
#    Binding_Affinity
# 0              75.0
# 1              67.5
# 3              55.0

# %%
df_valid_rows.tail()
# Out:
#   Molecule_Name                         SMILES  Solubility_Score  \
# 0       Aspirin       CC(=O)OC1=CC=CC=C1C(=O)O               1.2
# 1     Ibuprofen  CC(C)CC1=CC=C(C=C1)C(C)C(=O)O               0.8
# 3       Aspirin   CN1C=NC2=C1C(=O)N(C(=O)N2C)C               1.5
#
#    Binding_Affinity
# 0              75.0
# 1              67.5
# 3              55.0

# %%
df_valid_rows.to_csv("valid_smiles.csv",index=False)

# %%
check = pd.read_csv("valid_smiles.csv")

# %%
check.head()
# Out:
#   Molecule_Name                         SMILES  Solubility_Score  \
# 0       Aspirin       CC(=O)OC1=CC=CC=C1C(=O)O               1.2
# 1     Ibuprofen  CC(C)CC1=CC=C(C=C1)C(C)C(=O)O               0.8
# 2       Aspirin   CN1C=NC2=C1C(=O)N(C(=O)N2C)C               1.5
#
#    Binding_Affinity
# 0              75.0
# 1              67.5
# 2              55.0

# %%
check.tail()
# Out:
#   Molecule_Name                         SMILES  Solubility_Score  \
# 0       Aspirin       CC(=O)OC1=CC=CC=C1C(=O)O               1.2
# 1     Ibuprofen  CC(C)CC1=CC=C(C=C1)C(C)C(=O)O               0.8
# 2       Aspirin   CN1C=NC2=C1C(=O)N(C(=O)N2C)C               1.5
#
#    Binding_Affinity
# 0              75.0
# 1              67.5
# 2              55.0
